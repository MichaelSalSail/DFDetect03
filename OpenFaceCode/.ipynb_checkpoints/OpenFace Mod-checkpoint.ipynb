# %%
import openface
import cv2
import os
import matplotlib.pyplot as plt

# %%
fileDir = "/mnt/c/Users/Michael/Desktop/Michael All/VS_Projects/Senior Project II/DFDetect03/OpenFace Code"
modelDir = os.path.join(fileDir, 'models')
dlibModelDir = os.path.join(modelDir, 'dlib')
openfaceModelDir = os.path.join(modelDir, 'openface')

# %%
example = cv2.imread("images/examples/adams.jpg")
example_rgb = cv2.cvtColor(example, cv2.COLOR_BGR2RGB)
plt.imshow(example_rgb[:, :, ::-1 ]) 
plt.show()

# %%
# image_1=openface.AlignDlib()
# bbs = image_1.getAllFaceBoundingBoxes(example_rgb)
# align = AlignDlib.getAllFaceBoundingBoxes(example_rgb)
